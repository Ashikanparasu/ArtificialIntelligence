# %%
import pandas as pd

# %%
info = {
    "Name" : ["Ashik A", "Ashik2","Ashik3"],
    "CGPA" : [9.5,9.8,10]
}

df = pd.DataFrame(info)

print(df)
# Out:
#       Name  CGPA
# 0  Ashik A   9.5
# 1   Ashik2   9.8
# 2   Ashik3  10.0
