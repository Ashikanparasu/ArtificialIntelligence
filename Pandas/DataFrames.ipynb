# %%
import pandas as pd

# %%
info = {
    "Name" : ["Ashik A", "Ashik2","Ashik3"],
    "CGPA" : [9.5,9.8,10],
    "AGE" : [10,20,30]
}

df = pd.DataFrame(info)

print(df)
# Out:
#       Name  CGPA  AGE
# 0  Ashik A   9.5   10
# 1   Ashik2   9.8   20
# 2   Ashik3  10.0   30

# %%
df
# Out:
#       Name  CGPA  AGE
# 0  Ashik A   9.5   10
# 1   Ashik2   9.8   20
# 2   Ashik3  10.0   30

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
print(df.columns)
# Out:
# Index(['Name', 'CGPA', 'AGE'], dtype='object')

# %%
#import form numpy
import numpy as np
np_arr = np.array([[1,2,3],[4,5,6]])

df1= pd.DataFrame(np_arr , columns = ["A","B","C"])

print(df1)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
