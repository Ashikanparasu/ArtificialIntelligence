# %%
import requests

# %%
URL = "https://stephen-king-api.onrender.com/api/books"
res = request.get(URL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 URL = "https://stephen-king-api.onrender.com/api/books"
# ----> 2 res = request.get(URL)
#
# NameError: name 'request' is not defined
