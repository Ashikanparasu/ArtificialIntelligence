# %%
print("Hello World")
# Out:
# Hello World

# %%
print(10 + 12)
# Out:
# 22

# %%
a = 35 
print(a)
# Out:
# 35

# %%
def clean_data(data):
    for user in data:
        print(user)

# %%
clean_data(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 clean_data(data)
#
# NameError: name 'data' is not defined
